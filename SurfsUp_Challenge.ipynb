# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# Dependencies
import numpy as np

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# Import the sqlalchemy extract function.
from sqlalchemy import extract
import datetime as dt


# 1. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
start = dt.datetime(2017, 5, 31)

results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= start).all()

# 2. Convert the June temperatures to a list.
june_dates =[]
for result in results:
    june_dates.append(result)
    if result ==('2017-06-30', 0.08):
        break

# %%
# 3. Create a DataFrame from the list of temperatures for the month of June. 
import pandas as pd
df_june = pd.DataFrame(june_dates, columns=['Date','June Temps'])
df_june.head()
# Out:
#          Date  June Temps
# 0  2017-06-01        0.00
# 1  2017-06-02        0.00
# 2  2017-06-03        0.02
# 3  2017-06-04        0.00
# 4  2017-06-05        0.00

# %%
# 4. Calculate and print out the summary statistics for the June temperature DataFrame.
# Apply describe function 
df_june.describe()
# Out:
#        June Temps
# count   30.000000
# mean     0.012333
# std      0.024309
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.015000
# max      0.080000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.

# Import the sqlalchemy extract function.
from sqlalchemy import extract
import datetime as dt

start_Dec = dt.datetime(2016, 11, 30)


resultsDec = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= start_Dec).all()

# %%
print(resultsDec)
# Out:
# [('2016-12-01', 0.12), ('2016-12-02', 0.03), ('2016-12-03', 0.0), ('2016-12-04', 0.03), ('2016-12-05', 0.43), ('2016-12-06', 0.02), ('2016-12-07', 0.0), ('2016-12-08', 0.03), ('2016-12-09', 0.52), ('2016-12-10', 0.05), ('2016-12-11', 0.04), ('2016-12-12', 0.01), ('2016-12-13', 0.05), ('2016-12-14', 0.03), ('2016-12-15', 0.0), ('2016-12-16', 0.0), ('2016-12-17', 0.01), ('2016-12-18', 0.13), ('2016-12-19', 0.01), ('2016-12-20', 0.0), ('2016-12-21', 0.0), ('2016-12-22', 0.01), ('2016-12-23', 0.01), ('2016-12-24', 0.01), ('2016-12-25', 0.0), ('2016-12-26', 0.02), ('2016-12-27', 0.0), ('2016-12-28', 0.02), ('2016-12-29', 0.04), ('2016-12-30', 0.12), ('2016-12-31', 0.01), ('2017-01-01', 0.0), ('2017-01-02', 0.0), ('2017-01-03', 0.0), ('2017-01-04', 0.0), ('2017-01-05', 0.0), ('2017-01-06', 0.0), ('2017-01-07', 0.0), ('2017-01-08', 0.0), ('2017-01-09', 0.0), ('2017-01-10', 0.0), ('2017-01-11', 0.0), ('2017-01-12', 0.0), ('2017-01-13', 0.0), ('2017-01-14', 0.0), ('2017-01-15', 0.0), ('2017-0
# ...

# %%
# 7. Convert the December temperatures to a list.
dec_dates =[]
for result in resultsDec:
    dec_dates.append(result)
    if result ==('2017-12-31', 0.01):
        break

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
df_dec = pd.DataFrame(dec_dates, columns=['Date','December Temps'])
df_dec.head()
# Out:
#          Date  December Temps
# 0  2016-12-01            0.12
# 1  2016-12-02            0.03
# 2  2016-12-03            0.00
# 3  2016-12-04            0.03
# 4  2016-12-05            0.43

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
df_dec.describe()
# Out:
#        December Temps
# count     1445.000000
# mean         0.170062
# std          0.441790
# min          0.000000
# 25%          0.000000
# 50%          0.010000
# 75%          0.120000
# max          6.250000

# %%
# 10. Return to your challenge instructions to compare your summary statistics
